# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
c1 = [0.8095, 0.81, 0.81, 0.8095]
c2 = [0.737, 0.704, 0.734, 0.731]
c3 = [0.88, 0.8835, 0.8705, 0.882]
c4 = [0.84, 0.84, 0.84, 0.84]
c5 = [0.658, 0.658, 0.658, 0.658]
c6 = [0.632, 0.632, 0.632, 0.632]

plt.figure(figsize=(15,7))
x = ['No augmentation', 'by Discrimination', 'by Difficulty', 'by Guessing']
plt.plot(x, c1)
plt.plot(x, c2)
plt.plot(x, c3)
plt.plot(x, c4)
plt.plot(x, c5)
plt.plot(x, c6)


plt.ylabel('Acuracy')
plt.xlabel('Augmentation')
#plt.xticks(x)
labels = ['Decision Tree', 'Randon Forest', 'Neural Net', 'AdaBoost', 'Naive Bayes', 'QDA']
plt.legend(labels)
plt.plot()
# Out:
# []
