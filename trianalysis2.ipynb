# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
coef = pd.read_csv('/content/drive/MyDrive/TRI/Experimento1/Aumentação por chute/coef.csv')
#coef = pd.read_csv('/content/drive/MyDrive/TRI/Experimento1/coef.csv')
coef10 = pd.read_csv('/content/drive/MyDrive/TRI/FASE2/10/coef.csv')
coef25 = pd.read_csv('/content/drive/MyDrive/TRI/FASE2/25/coef.csv')
coef50 = pd.read_csv('/content/drive/MyDrive/TRI/FASE2/50/coef.csv')
coef75 = pd.read_csv('/content/drive/MyDrive/TRI/FASE2/75/coef.csv')
coef90 = pd.read_csv('/content/drive/MyDrive/TRI/FASE2/90/coef.csv')

# %%
#coef10 = pd.read_csv('/content/drive/MyDrive/TRI/FASE4/all10/coef.csv')

# %%
coef
# Out:
#             Unnamed: 0       par
# 0             Item.1.a  3.482765
# 1             Item.1.b -0.549428
# 2             Item.1.g  0.064402
# 3             Item.1.u  0.987995
# 4             Item.2.a  3.864013
# ...                ...       ...
# 3997       Item.1000.b -0.549428
# 3998       Item.1000.g  0.064402
# 3999       Item.1000.u  0.987995
# 4000  GroupPars.MEAN_1  0.000000
# 4001  GroupPars.COV_11  1.000000
#
# [4002 rows x 2 columns]

# %%
def formatar(coef): 
  nitens = 1000
  ncoef = 4
  totalvalues = nitens * ncoef
  
  a = []
  for i in range(0, totalvalues, 4):
    a.append(coef.iloc[i][1]) 
  b = []
  for i in range(1, totalvalues, 4):
    b.append(coef.iloc[i][1]) 
  c = []
  for i in range(2, totalvalues, 4):
    c.append(coef.iloc[i][1])
  d = [] 
  for i in range(3, totalvalues, 4):
    d.append(coef.iloc[i][1]) 

  df = pd.DataFrame({'itens': range(1, nitens + 1 ),
                   'a': a,
                   'b': b,
                   'c': c,
                   'd': d
                   })
  return df

# %%
df = formatar(coef)
#df10 = formatar(coef10)
#df25 = formatar(coef25)
#df50 = formatar(coef50)
#df75 = formatar(coef75)
#df90 = formatar(coef90)

# %%
df
# Out:
#      itens         a         b         c         d
# 0        1  3.482765 -0.549428  0.064402  0.987995
# 1        2  3.864013  0.601174  0.016500  0.951330
# 2        3  2.016149  0.262965  0.049192  0.951978
# 3        4  3.864013  0.601174  0.016500  0.951330
# 4        5  3.482765 -0.549428  0.064402  0.987995
# ..     ...       ...       ...       ...       ...
# 995    996  1.722074 -2.438087  0.085804  0.996528
# 996    997  3.493739  1.194679  0.006600  0.938805
# 997    998  1.722074 -2.438087  0.085804  0.996528
# 998    999  1.722074 -2.438087  0.085804  0.996528
# 999   1000  3.482765 -0.549428  0.064402  0.987995
#
# [1000 rows x 5 columns]

# %%
df_ordenado = df.sort_values(by='b', ascending=False) #
#df_ordenado.head()
df_ordenado.loc[(df_ordenado['itens'] > 680) & (df_ordenado['itens'] < 690)].head(10)
# Out:
#      itens         a         b         c         d
# 688    689  2.043285  2.492501  0.004626  0.731216
# 681    682  1.913696  1.206371  0.112265  0.934789
# 684    685  3.493739  1.194679  0.006600  0.938805
# 683    684  1.942913  0.956670  0.055361  0.941010
# 685    686  1.942913  0.956670  0.055361  0.941010
# 680    681  1.944644  0.954837  0.055118  0.941037
# 682    683  2.912763  0.706551  0.026107  0.659581
# 686    687  3.681872  0.601844  0.017515  0.950434
# 687    688  3.681872  0.601844  0.017515  0.950434

# %%
idx_chutes =
[96, 67, 20, 16, 51, 15, 18, 91, 44, 35],
[138, 104, 106, 103, 102, 107, 108, 109, 110, 111],
[232, 209, 269, 251, 260, 279, 253, 280, 242, 214],
[393, 349, 347, 332, 350, 394, 369, 304, 387, 379],
[443, 487, 410, 495, 436, 453, 458, 428, 482, 451],
[549, 544, 578, 599, 594, 515, 520, 536, 561, 514],
[635, 674, 665, 636, 641, 610, 606, 643, 679, 682],
[744, 703, 727, 747, 734, 759, 740, 705, 715, 735],
[897, 856, 868, 861, 889, 875, 832, 888, 823, 878],
[927, 995, 990, 918, 913, 998, 907, 942, 954, 946]

# %%
idx_maisdiscriminantes = 
[88, 2, 73, 17, 66, 46, 87, 52, 21, 71],
[192, 140, 147, 115, 179, 138, 148, 113, 132, 178],
[262, 238, 205, 237, 240, 272, 271, 292, 298, 239],
[321, 395, 371, 396, 370, 391, 368, 383, 359, 324],
[434, 469, 422, 431, 439, 441, 454, 455, 478, 492],
[596, 572, 551, 540, 535, 531, 528, 521, 519, 518],
[609, 622, 646, 634, 694, 691, 676, 670, 650, 644],
[703, 761, 774, 798, 770, 727, 789, 796, 795, 794],
[899, 858, 894, 862, 893, 859, 838, 872, 892, 829],
[941, 910, 984, 991, 972, 971, 970, 932, 956, 937]

# %%
idx_maisdificeis = 
[83, 63, 36, 90, 45, 48, 49, 50, 54, 55],
[123, 138, 105, 183, 184, 172, 158, 120, 140, 192], 
[210, 252, 217, 278, 290, 255, 279, 280, 253, 260],
[362, 373, 329, 354, 374, 333, 347, 395, 394, 352],
[496, 474, 476, 446, 429, 420, 468, 436, 487, 495],
[598, 523, 570, 564, 560, 509, 548, 550, 503, 591],
[698, 620, 672, 659, 655, 611, 614, 678, 648, 626],
[727, 703, 744, 724, 742, 712, 761, 774, 770, 798],
[868, 867, 824, 812, 819, 891, 835, 834, 842, 887],
[904, 902, 916, 957, 977, 988, 989, 936, 924, 961]

# %%
dfplot = pd.DataFrame({'discrimination':  np.concatenate((np.array(df10['a']) ,  np.array(df25['a']) ,  np.array(df50['a']) ,  np.array(df75['a']) ,  np.array(df90['a'])), axis=None),
                       'difficulty':  np.concatenate((np.array(df10['b']) ,  np.array(df25['b']) ,  np.array(df50['b']) ,  np.array(df75['b']), np.array(df90['b'])), axis=None),
                       'guessing':  np.concatenate((np.array(df10['c']) ,  np.array(df25['c']) ,  np.array(df50['c']) ,  np.array(df75['c']), np.array(df90['c'])), axis=None),
                       'augmentation rate': ['10%']*1000 + ['25%']*1000 + ['50%']*1000 + ['75%']*1000 + ['90%']*1000,
                   })

# %%
dfplot
# Out:
#       discrimination  difficulty      guessing augmentation rate
# 0           1.777125    2.745632  3.897574e-03               10%
# 1           3.342618    1.185888  7.118706e-03               10%
# 2           1.777125    2.745632  3.897574e-03               10%
# 3           1.777125    2.745632  3.897574e-03               10%
# 4           2.177579    1.270676  4.372444e-02               10%
# ...              ...         ...           ...               ...
# 4995       59.180128   -0.404085  5.650914e-07               90%
# 4996       59.180128   -0.404085  5.650914e-07               90%
# 4997       10.940117   -1.604071  1.133552e-06               90%
# 4998       59.180128   -0.404085  5.650914e-07               90%
# 4999       59.180128   -0.404085  5.650914e-07               90%
#
# [5000 rows x 4 columns]

# %%
#sns.swarmplot(x="augmentation rate", y="difficulty", data=dfplot, palette="Set2", dodge=True)
plt.savefig("/content/drive/MyDrive/TRI/FASE3/Plots/diff_augm.png")

# %%
def mediasb(df):
  medias = [df['b'][0:100].mean(), df['b'][100:200].mean(), df['b'][200:300].mean(), df['b'][300:400].mean(), 
            df['b'][400:500].mean(), df['b'][500:600].mean(), df['b'][600:700].mean(),
            df['b'][700:800].mean(), df['b'][800:900].mean(), df['b'][900:1000].mean()]
  return medias

# %%
med10 = mediasb(df10)
med25 = mediasb(df25)
med50 = mediasb(df50)
med75 = mediasb(df75)
med90 = mediasb(df90)

c1 = [med10[0], med25[0], med50[0], med75[0], med90[0]]
c2 = [med10[1], med25[1], med50[1], med75[1], med90[1]]
c3 = [med10[2], med25[2], med50[2], med75[2], med90[2]]
c4 = [med10[3], med25[3], med50[3], med75[3], med90[3]]
c5 = [med10[4], med25[4], med50[4], med75[4], med90[4]]
c6 = [med10[5], med25[5], med50[5], med75[5], med90[5]]
c7 = [med10[6], med25[6], med50[6], med75[6], med90[6]]
c8 = [med10[7], med25[7], med50[7], med75[7], med90[7]]
c9 = [med10[8], med25[8], med50[8], med75[8], med90[8]]
c10 = [med10[9], med25[9], med50[9], med75[9], med90[9]]

# %%
plt.clf() 
plt.figure(figsize=(15,7))
x = ['10%', '25%', '50%', '75%', '90%']
plt.plot(x, c1)
plt.plot(x, c2)
plt.plot(x, c3)
plt.plot(x, c4)
plt.plot(x, c5)
plt.plot(x, c6)
plt.plot(x, c7)
plt.plot(x, c8)
plt.plot(x, c9)
plt.plot(x, c10)

plt.ylabel('Difficulty standard')
plt.xlabel('Augmentation Rate')
#plt.xticks(x)
labels = ['Camiseta', 'Calça', 'Suéter', 'Vestido', 'Casaco',
               'Sandalia', 'Camisa', 'Tênis', 'Bolsa', 'Botas']
plt.legend(labels)
plt.plot()
plt.savefig("/content/drive/MyDrive/TRI/FASE3/Plots/diff-std_augm.png")

# %%
plt.figure(figsize=(6,5))
plt.prism()
sns.set(style="whitegrid")
sns.barplot(x="augmentation rate", y="discrimination", data=dfplot, capsize=.25, ci="sd")
#sns.swarmplot(x="augmentation rate", y="discrimination", data=dfplot, palette="Set2", dodge=True)
plt.savefig("/content/drive/MyDrive/TRI/FASE3/Plots/disc_augm.png")

# %%
def mediasa(df):
  medias = [df['a'][0:100].mean(), df['a'][100:200].mean(), df['a'][200:300].mean(), df['a'][300:400].mean(), 
            df['a'][400:500].mean(), df['a'][500:600].mean(), df['a'][600:700].mean(),
            df['a'][700:800].mean(), df['a'][800:900].mean(), df['a'][900:1000].mean()]
  return medias

# %%
med10 = mediasa(df10)
med25 = mediasa(df25)
med50 = mediasa(df50)
med75 = mediasa(df75)
med90 = mediasa(df90)

c1 = [med10[0], med25[0], med50[0], med75[0], med90[0]]
c2 = [med10[1], med25[1], med50[1], med75[1], med90[1]]
c3 = [med10[2], med25[2], med50[2], med75[2], med90[2]]
c4 = [med10[3], med25[3], med50[3], med75[3], med90[3]]
c5 = [med10[4], med25[4], med50[4], med75[4], med90[4]]
c6 = [med10[5], med25[5], med50[5], med75[5], med90[5]]
c7 = [med10[6], med25[6], med50[6], med75[6], med90[6]]
c8 = [med10[7], med25[7], med50[7], med75[7], med90[7]]
c9 = [med10[8], med25[8], med50[8], med75[8], med90[8]]
c10 = [med10[9], med25[9], med50[9], med75[9], med90[9]]

# %%
plt.clf() 
plt.figure(figsize=(15,7))
x = ['10%', '25%', '50%', '75%', '90%']
plt.plot(x, c1)
plt.plot(x, c2)
plt.plot(x, c3)
plt.plot(x, c4)
plt.plot(x, c5)
plt.plot(x, c6)
plt.plot(x, c7)
plt.plot(x, c8)
plt.plot(x, c9)
plt.plot(x, c10)

plt.ylabel('Discrimination standard')
plt.xlabel('Augmentation Rate')
#plt.xticks(x)
labels = ['Camiseta', 'Calça', 'Suéter', 'Vestido', 'Casaco',
               'Sandalia', 'Camisa', 'Tênis', 'Bolsa', 'Botas']
plt.legend(labels)
plt.savefig("/content/drive/MyDrive/TRI/FASE3/Plots/disc-std_augm.png")

# %%
plt.figure(figsize=(6,5))
plt.prism()
sns.set(style="whitegrid")
sns.barplot(x="augmentation rate", y="guessing", data=dfplot, capsize=.25, ci="sd")
#sns.swarmplot(x="augmentation rate", y="guessing", data=dfplot, palette="Set2", dodge=True)
plt.savefig("/content/drive/MyDrive/TRI/FASE3/Plots/guess_augm.png")

# %%
def mediasc(df):
  medias = [df['c'][0:100].mean(), df['c'][100:200].mean(), df['c'][200:300].mean(), df['c'][300:400].mean(), 
            df['c'][400:500].mean(), df['c'][500:600].mean(), df['c'][600:700].mean(),
            df['c'][700:800].mean(), df['c'][800:900].mean(), df['c'][900:1000].mean()]
  return medias

# %%
med10 = mediasc(df10)
med25 = mediasc(df25)
med50 = mediasc(df50)
med75 = mediasc(df75)
med90 = mediasc(df90)

c1 = [med10[0], med25[0], med50[0], med75[0], med90[0]]
c2 = [med10[1], med25[1], med50[1], med75[1], med90[1]]
c3 = [med10[2], med25[2], med50[2], med75[2], med90[2]]
c4 = [med10[3], med25[3], med50[3], med75[3], med90[3]]
c5 = [med10[4], med25[4], med50[4], med75[4], med90[4]]
c6 = [med10[5], med25[5], med50[5], med75[5], med90[5]]
c7 = [med10[6], med25[6], med50[6], med75[6], med90[6]]
c8 = [med10[7], med25[7], med50[7], med75[7], med90[7]]
c9 = [med10[8], med25[8], med50[8], med75[8], med90[8]]
c10 = [med10[9], med25[9], med50[9], med75[9], med90[9]]

# %%
plt.clf() 
plt.figure(figsize=(15,7))
x = ['10%', '25%', '50%', '75%', '90%']
plt.plot(x, c1)
plt.plot(x, c2)
plt.plot(x, c3)
plt.plot(x, c4)
plt.plot(x, c5)
plt.plot(x, c6)
plt.plot(x, c7)
plt.plot(x, c8)
plt.plot(x, c9)
plt.plot(x, c10)

plt.ylabel('Guessing standard')
plt.xlabel('Augmentation Rate')
#plt.xticks(x)
labels = ['Camiseta', 'Calça', 'Suéter', 'Vestido', 'Casaco',
               'Sandalia', 'Camisa', 'Tênis', 'Bolsa', 'Botas']
plt.legend(labels)
plt.savefig("/content/drive/MyDrive/TRI/FASE3/Plots/guess-std_augm.png")

# %%
acc10 = pd.read_csv('/content/drive/MyDrive/TRI/FASE2/Accuracy/acc10.csv')
acc25 = pd.read_csv('/content/drive/MyDrive/TRI/FASE2/Accuracy/acc25.csv')
acc50 = pd.read_csv('/content/drive/MyDrive/TRI/FASE2/Accuracy/acc50.csv')
acc75 = pd.read_csv('/content/drive/MyDrive/TRI/FASE2/Accuracy/acc75.csv')
acc90 = pd.read_csv('/content/drive/MyDrive/TRI/FASE2/Accuracy/acc90.csv')

#acc10 = pd.read_csv('/content/drive/MyDrive/TRI/FASE2/10/scores.csv')
#acc25 = pd.read_csv('/content/drive/MyDrive/TRI/FASE2/25/scores.csv')
#acc50 = pd.read_csv('/content/drive/MyDrive/TRI/FASE2/50/scores.csv')
#acc75 = pd.read_csv('/content/drive/MyDrive/TRI/FASE2/75/scores.csv')
#acc90 = pd.read_csv('/content/drive/MyDrive/TRI/FASE2/90/scores.csv')

# %%
acc10
# Out:
#    Unnamed: 0    classifiers  scores
# 0           0  Decision Tree  0.6409
# 1           1  Random Forest  0.6676
# 2           2     Neural Net  0.8148
# 3           3       AdaBoost  0.4995
# 4           4    Naive Bayes  0.5925
# 5           5            QDA  0.5217

# %%
DT = [acc10["scores"][0], acc25["scores"][0], acc50["scores"][0], acc75["scores"][0], acc90["scores"][0]]
RF = [acc10["scores"][1], acc25["scores"][1], acc50["scores"][1], acc75["scores"][1], acc90["scores"][1]]
NN = [acc10["scores"][2], acc25["scores"][2], acc50["scores"][2], acc75["scores"][2], acc90["scores"][2]]
AB = [acc10["scores"][3], acc25["scores"][3], acc50["scores"][3], acc75["scores"][3], acc90["scores"][3]]
NB = [acc10["scores"][4], acc25["scores"][4], acc50["scores"][4], acc75["scores"][4], acc90["scores"][4]]
QDA = [acc10["scores"][5], acc25["scores"][5], acc50["scores"][5], acc75["scores"][5], acc90["scores"][5]]

# %%
DT = [acc10["F1"][0], acc25["F1"][0], acc50["F1"][0], acc75["F1"][0], acc90["F1"][0]]
RF = [acc10["F1"][1], acc25["F1"][1], acc50["F1"][1], acc75["F1"][1], acc90["F1"][1]]
NN = [acc10["F1"][2], acc25["F1"][2], acc50["F1"][2], acc75["F1"][2], acc90["F1"][2]]
AB = [acc10["F1"][3], acc25["F1"][3], acc50["F1"][3], acc75["F1"][3], acc90["F1"][3]]
NB = [acc10["F1"][4], acc25["F1"][4], acc50["F1"][4], acc75["F1"][4], acc90["F1"][4]]
QDA = [acc10["F1"][5], acc25["F1"][5], acc50["F1"][5], acc75["F1"][5], acc90["F1"][5]]

# %%
plt.clf() 
plt.figure(figsize=(15,7))
x = ['10%', '25%', '50%', '75%', '90%']
plt.plot(x, DT)
plt.plot(x, RF)
plt.plot(x, NN)
plt.plot(x, AB)
plt.plot(x, NB)
plt.plot(x, QDA)

plt.ylabel('Accuracy')
plt.xlabel('Augmentation Rate')
#plt.xticks(x)
sns.set(style="whitegrid")
labels = ['Decision Tree', 'Randon Forest', 'Neural Net', 'AdaBoost', 'Naive Bayes', 'QDA']
plt.legend(labels)
plt.savefig("/content/drive/MyDrive/TRI/FASE3/Plots/acc_modelXaugm.png")

# %%
acc10_classe = pd.read_csv('/content/drive/MyDrive/TRI/FASE2/Accuracy/acc10_classe.csv', index_col=0)
acc25_classe = pd.read_csv('/content/drive/MyDrive/TRI/FASE2/Accuracy/acc25_classe.csv', index_col=0)
acc50_classe = pd.read_csv('/content/drive/MyDrive/TRI/FASE2/Accuracy/acc50_classe.csv', index_col=0)
acc75_classe = pd.read_csv('/content/drive/MyDrive/TRI/FASE2/Accuracy/acc75_classe.csv', index_col=0)
acc90_classe = pd.read_csv('/content/drive/MyDrive/TRI/FASE2/Accuracy/acc90_classe.csv', index_col=0)

# %%
acc10_classe
# Out:
#    Decision Tree  Random Forest  Neural Net  AdaBoost  Naive Bayes    QDA
# 0          0.000          0.000       0.369     0.010        0.680  0.000
# 1          0.809          0.881       0.976     0.774        0.939  0.944
# 2          0.610          0.622       0.783     0.671        0.314  0.237
# 3          0.838          0.868       0.811     0.665        0.538  0.528
# 4          0.767          0.444       0.839     0.358        0.779  0.545
# 5          0.744          0.757       0.950     0.325        0.278  0.215
# 6          0.175          0.471       0.618     0.200        0.033  0.239
# 7          0.832          0.889       0.875     0.965        0.988  0.978
# 8          0.769          0.829       0.948     0.831        0.710  0.821
# 9          0.865          0.915       0.979     0.196        0.666  0.710

# %%
dfplot2 = pd.DataFrame({'discrimination':  np.concatenate((np.array(df10['a']) ,  np.array(df25['a']) ,  np.array(df50['a']) ,  np.array(df75['a']) ,  np.array(df90['a'])), axis=None),
                       'difficulty':  np.concatenate((np.array(df10['b']) ,  np.array(df25['b']) ,  np.array(df50['b']) ,  np.array(df75['b']), np.array(df90['b'])), axis=None),
                       'guessing':  np.concatenate((np.array(df10['c']) ,  np.array(df25['c']) ,  np.array(df50['c']) ,  np.array(df75['c']), np.array(df90['c'])), axis=None),
                       'augmentation rate': ['10%']*1000 + ['25%']*1000 + ['50%']*1000 + ['75%']*1000 + ['90%']*1000,
                   })

# %%
plt.figure(figsize=(6,5))
plt.prism()
sns.set(style="whitegrid")
sns.barplot(x="augmentation rate", y="guessing", data=dfplot, capsize=.25, ci="sd")
#sns.swarmplot(x="augmentation rate", y="guessing", data=dfplot, palette="Set2", dodge=True)
plt.savefig("/content/drive/MyDrive/TRI/FASE3/Plots/guess_augm.png")

# %%
def mediasAcc(df):
  medias = [np.array(df.iloc[0]).mean(), np.array(df.iloc[1]).mean(), np.array(df.iloc[2]).mean(),
            np.array(df.iloc[3]).mean(), np.array(df.iloc[4]).mean(), np.array(df.iloc[5]).mean(),
            np.array(df.iloc[6]).mean(), np.array(df.iloc[7]).mean(), np.array(df.iloc[8]).mean(), 
            np.array(df.iloc[9]).mean()]

  return medias

# %%
med10 = mediasAcc(acc10_classe)
med25 = mediasAcc(acc25_classe)
med50 = mediasAcc(acc50_classe)
med75 = mediasAcc(acc75_classe)
med90 = mediasAcc(acc90_classe)

c1 = [med10[0], med25[0], med50[0], med75[0], med90[0]]
c2 = [med10[1], med25[1], med50[1], med75[1], med90[1]]
c3 = [med10[2], med25[2], med50[2], med75[2], med90[2]]
c4 = [med10[3], med25[3], med50[3], med75[3], med90[3]]
c5 = [med10[4], med25[4], med50[4], med75[4], med90[4]]
c6 = [med10[5], med25[5], med50[5], med75[5], med90[5]]
c7 = [med10[6], med25[6], med50[6], med75[6], med90[6]]
c8 = [med10[7], med25[7], med50[7], med75[7], med90[7]]
c9 = [med10[8], med25[8], med50[8], med75[8], med90[8]]
c10 = [med10[9], med25[9], med50[9], med75[9], med90[9]]

# %%
plt.clf() 
plt.figure(figsize=(15,7))
x = ['10%', '25%', '50%', '75%', '90%']
plt.plot(x, c1)
plt.plot(x, c2)
plt.plot(x, c3)
plt.plot(x, c4)
plt.plot(x, c5)
plt.plot(x, c6)
plt.plot(x, c7)
plt.plot(x, c8)
plt.plot(x, c9)
plt.plot(x, c10)

plt.ylabel('Accuracy standard')
plt.xlabel('Augmentation Rate')
#plt.xticks(x)
labels = ['Camiseta', 'Calça', 'Suéter', 'Vestido', 'Casaco',
               'Sandalia', 'Camisa', 'Tênis', 'Bolsa', 'Botas']
plt.legend(labels)
plt.savefig("/content/drive/MyDrive/TRI/FASE3/Plots/Acc_classe_stdXaugm.png")
